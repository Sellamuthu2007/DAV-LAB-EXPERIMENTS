# %%
import pandas as pd
# Load dataset into a DataFrame
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
# Display first and last few rows
print("First 5 rows:\n", df.head())
print("Last 5 rows:\n", df.tail())
# Check data types and general info
df.info()
# Summary statistics
print("Summary statistics:\n", df.describe())
# Handle missing values
df.fillna(df.mean(numeric_only=True), inplace=True) # Added numeric_only=True for df.mean()
# Create a new column
df['new_column'] = df['median_income'] * 2
# Create a Series and perform operations
series = df['median_income']
print("Series addition:", series + 10)
# Filter rows based on conditions
filtered_df = df[(df['median_income'] > 5) & (df['housing_median_age'] < 30)] # Adjusted filter conditions for the new columns
print("Filtered DataFrame:\n", filtered_df)
# Grouping and aggregation
grouped = df.groupby('housing_median_age')['median_house_value'].mean()
print("Grouped mean:\n", grouped)
# Sorting
df_sorted = df.sort_values(by='median_house_value', ascending=False)
print("Sorted DataFrame:\n", df_sorted)
# Boolean masking
masked_df = df[df['median_house_value'] > df['median_house_value'].median()]

print("Masked DataFrame:\n", masked_df)
# Remove duplicates and drop missing values
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# Create a new DataFrame with selected columns
subset_df = df[['longitude', 'latitude']]
# Save the new DataFrame to a CSV file
subset_df.to_csv('filtered_data.csv', index=False)
# Compute summary statistics
print("Total sum:", df['median_house_value'].sum())
print("Mean:", df['median_house_value'].mean())
print("Standard Deviation:", df['median_house_value'].std())
# Out:
# First 5 rows:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
# Last 5 rows:
#         longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# ...

# %% [markdown]
# ### Capture Cell Output and Save as Image
#
# To get the entire text output of the previous cell as a single image, we can redirect the standard output (`sys.stdout`) to capture all printed text and then use `matplotlib` to render this captured text onto a figure, which can then be saved as an image file (e.g., PNG).
